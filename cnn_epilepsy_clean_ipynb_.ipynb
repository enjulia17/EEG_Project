# %% [markdown]
# Notebook based off of https://arxiv.org/pdf/1801.05412.pdf , refer to this for parameters.

# %% [markdown]
# # Import of necesary librairies

# %%
import pandas as pd
import glob
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout
from keras.layers import Embedding, Activation, Flatten
from keras.layers import Conv1D, GlobalAveragePooling1D, MaxPooling1D, BatchNormalization
from keras.utils import to_categorical
from keras import optimizers
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder

import time
from IPython.display import Image
from IPython.core.display import HTML
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# # Utilitaries functions

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/bonn_uni_datasets/
#    creating: data/bonn_uni_datasets/A/
#   inflating: data/bonn_uni_datasets/A/Z001.txt
#   inflating: data/bonn_uni_datasets/A/Z002.txt
#   inflating: data/bonn_uni_datasets/A/Z003.txt
#   inflating: data/bonn_uni_datasets/A/Z004.txt
#   inflating: data/bonn_uni_datasets/A/Z005.txt
#   inflating: data/bonn_uni_datasets/A/Z006.txt
#   inflating: data/bonn_uni_datasets/A/Z007.txt
#   inflating: data/bonn_uni_datasets/A/Z008.txt
#   inflating: data/bonn_uni_datasets/A/Z009.txt
#   inflating: data/bonn_uni_datasets/A/Z010.txt
#   inflating: data/bonn_uni_datasets/A/Z011.txt
#   inflating: data/bonn_uni_datasets/A/Z012.txt
#   inflating: data/bonn_uni_datasets/A/Z013.txt
#   inflating: data/bonn_uni_datasets/A/Z014.txt
#   inflating: data/bonn_uni_datasets/A/Z015.txt
#   inflating: data/bonn_uni_datasets/A/Z016.txt
#   inflating: data/bonn_uni_datasets/A/Z017.txt
#   inflating: data/bonn_uni_datasets/A/Z018.txt
#   inflating: data/bonn_uni_datasets/A/Z019.txt
#   inflating: data/bonn_uni_datasets/A/Z020.txt
#   inflating: data/bonn_uni_datasets/A/Z021.txt
#   inflating: data/bonn_uni_datasets/A/Z022.txt
#   inflating: data/bonn_uni_datasets/A/Z023.txt
#   inflating: data/bonn_uni_datasets/A/Z024.txt
#   inflating: data/bonn_uni_datasets/A/Z025.txt
#   inflating: data/bonn_uni_datasets/A/Z026.txt
#   inflating: data/bonn_uni_datasets/A/Z027.txt
#   inflating: data/bonn_uni_datasets/A/Z028.txt
#   inflating: data/bonn_uni_datasets/A/Z029.txt
#   inflating: data/bonn_uni_datasets/A/Z030.txt
#   inflating: data/bonn_uni_datasets/A/Z031.txt
#   inflating: data/bonn_uni_datasets/A/Z032.txt
#   inflating: data/bonn_uni_datasets/A/Z033.txt
#   inflating: data/bonn_uni_datasets/A/Z034.txt
#   inflating: data/bonn_uni_datasets/A/Z035.txt
#   inflating: data/bonn_uni_datasets/A/Z036.txt
#   inflating: data/bonn_uni_datasets/A/Z037.txt
#   inflating: data/bonn_uni_datasets/A/Z038.txt
#   inflating: data/bonn_uni_datasets/A/Z039.txt
#   inflating: data/bonn_uni_datasets/A/Z040.txt
#   inflating: data/bonn_uni_datasets/A/Z041.txt
#   inflating: data/bonn_uni_datasets/A/Z042.txt
#   inflating: data/bonn_uni_datasets/A/Z043.txt
#   inflating: data/bonn_uni_datasets/A/Z044.txt
#   inflating: data/bonn_uni_datasets/A/Z045.txt
#   inflating: data/bonn_uni_datasets/A/Z046.txt
#   inflating: data/bonn_uni_datasets/A/Z047.txt
#   inflating: data/bonn_uni_datasets/A/Z048.txt
#   inflating: data/bonn_uni_datasets/A/Z049.txt
#   inflating: data/bonn_uni_datasets/A/Z050.txt
#   inflating: data/bonn_uni_datasets/A/Z051.txt
#   inflating: data/bonn_uni_datasets/A/Z052.txt
#   inflating: data/bonn_uni_datasets/A/Z053.txt
#   inflating: data/bonn_uni_datasets/A/Z054.txt
#   inflating: data/bonn_uni_datasets/A/Z055.txt
#   inflating: data/bonn_uni_datasets/A/Z056.txt
#   inflating: data/bonn_uni_datasets/A/Z057.txt
#   inflating: data/bonn_uni_datasets/A/Z058.txt
#   inflating: data/bonn_uni_datasets/A/Z059.txt
#   inflating: data/bonn_uni_datasets/A/Z060.txt
#   inflating: data/bonn_uni_datasets/A/Z061.txt
#   inflating: data/bonn_uni_datasets/A/Z062.txt
#   inflating: data/bonn_uni_datasets/A/Z063.txt
#   inflating: data/bonn_uni_datasets/A/Z064.txt
#   inflating: data/bonn_uni_datasets/A/Z065.txt
#   inflating: data/bonn_uni_datasets/A/Z066.txt
#   inflating: data/bonn_uni_datasets/A/Z067.txt
#   inflating: data/bonn_uni_datasets/A/Z068.txt
#   inflating: data/bonn_uni_datasets/A/Z069.txt
#   inflating: data/bonn_uni_datasets/A/Z070.txt
#   inflating: data/bonn_uni_datasets/A/Z071.txt
#   inflating: data/bonn_uni_datasets/A/Z072.txt
#   inflating: data/bonn_uni_datasets/A/Z073.txt
#   inflating: data/bonn_uni_datasets/A/Z074.txt
#   inflating: data/bonn_uni_datasets/A/Z075.txt
#   inflating: data/bonn_uni_datasets/A/Z076.txt
#   inflating: data/bonn_uni_datasets/A/Z077.txt
#   inflating: data/bonn_uni_datasets/A/Z078.txt
#   inflating: data/bonn_uni_datasets/A/Z079.txt
#   inflating: data/bonn_uni_datasets/A/Z080.txt
#   inflating: data/bonn_uni_datasets/A/Z081.txt
#   inflating: data/bonn_uni_datasets/A/Z082.txt
#   inflating: data/bonn_uni_datasets/A/Z083.txt
#   inflating: data/bonn_uni_datasets/A/Z084.txt
#   inflating: data/bonn_uni_datasets/A/Z085.txt
#   inflating: data/bonn_uni_datasets/A/Z086.txt
#   inflating: data/bonn_uni_datasets/A/Z087.txt
#   inflating: data/bonn_uni_datasets/A/Z088.txt
#   inflating: data/bonn_uni_datasets/A/Z089.txt
#   inflating: data/bonn_uni_datasets/A/Z090.txt
#   inflating: data/bonn_uni_datasets/A/Z091.txt
#   inflating: data/bonn_uni_datasets/A/Z092.txt
#   inflating: data/bonn_uni_datasets/A/Z093.txt
#   inflating: data/bonn_uni_datasets/A/Z094.txt
#   inflating: data/bonn_uni_datasets/A/Z095.txt
#   inflating: data/bonn_uni_datasets/A/Z096.txt
#   inflating: data/bonn_uni_datasets/A/Z097.txt
#   inflating: data/bonn_uni_datasets/A/Z098.txt
#   inflating: data/bonn_uni_datasets/A/Z099.txt
#   inflating: data/bonn_uni_datasets/A/Z100.txt
#    creating: data/bonn_uni_datasets/B/
#   inflating: data/bonn_uni_datasets/B/O001.txt
#   inflating: data/bonn_uni_datasets/B/O002.txt
#   inflating: data/bonn_uni_datasets/B/O003.txt
#   inflating: data/bonn_uni_datasets/B/O004.txt
#   inflating: data/bonn_uni_datasets/B/O005.txt
#   inflating: data/bonn_uni_datasets/B/O006.txt
#   inflating: data/bonn_uni_datasets/B/O007.txt
#   inflating: data/bonn_uni_datasets/B/O008.txt
#   inflating: data/bonn_uni_datasets/B/O009.txt
#   inflating: data/bonn_uni_datasets/B/O010.txt
#   inflating: data/bonn_uni_datasets/B/O011.txt
#   inflating: data/bonn_uni_datasets/B/O012.txt
#   inflating: data/bonn_uni_datasets/B/O013.txt
#   inflating: data/bonn_uni_datasets/B/O014.txt
#   inflating: data/bonn_uni_datasets/B/O015.txt
#   inflating: data/bonn_uni_datasets/B/O016.txt
#   inflating: data/bonn_uni_datasets/B/O017.txt
#   inflating: data/bonn_uni_datasets/B/O018.txt
#   inflating: data/bonn_uni_datasets/B/O019.txt
#   inflating: data/bonn_uni_datasets/B/O020.txt
#   inflating: data/bonn_uni_datasets/B/O021.txt
#   inflating: data/bonn_uni_datasets/B/O022.txt
#   inflating: data/bonn_uni_datasets/B/O023.txt
#   inflating: data/bonn_uni_datasets/B/O024.txt
#   inflating: data/bonn_uni_datasets/B/O025.txt
#   inflating: data/bonn_uni_datasets/B/O026.txt
#   inflating: data/bonn_uni_datasets/B/O027.txt
#   inflating: data/bonn_uni_datasets/B/O028.txt
#   inflating: data/bonn_uni_datasets/B/O029.txt
#   inflating: data/bonn_uni_datasets/B/O030.txt
#   inflating: data/bonn_uni_datasets/B/O031.txt
#   inflating: data/bonn_uni_datasets/B/O032.txt
#   inflating: data/bonn_uni_datasets/B/O033.txt
#   inflating: data/bonn_uni_datasets/B/O034.txt
#   inflating: data/bonn_uni_datasets/B/O035.txt
#   inflating: data/bonn_uni_datasets/B/O036.txt
#   inflating: data/bonn_uni_datasets/B/O037.txt
#   inflating: data/bonn_uni_datasets/B/O038.txt
#   inflating: data/bonn_uni_datasets/B/O039.txt
#   inflating: data/bonn_uni_datasets/B/O040.txt
#   inflating: data/bonn_uni_datasets/B/O041.txt
#   inflating: data/bonn_uni_datasets/B/O042.txt
#   inflating: data/bonn_uni_datasets/B/O043.txt
#   inflating: data/bonn_uni_datasets/B/O044.txt
#   inflating: data/bonn_uni_datasets/B/O045.txt
#   inflating: data/bonn_uni_datasets/B/O046.txt
#   inflating: data/bonn_uni_datasets/B/O047.txt
#   inflating: data/bonn_uni_datasets/B/O048.txt
#   inflating: data/bonn_uni_datasets/B/O049.txt
#   inflating: data/bonn_uni_datasets/B/O050.txt
#   inflating: data/bonn_uni_datasets/B/O051.txt
#   inflating: data/bonn_uni_datasets/B/O052.txt
#   inflating: data/bonn_uni_datasets/B/O053.txt
#   inflating: data/bonn_uni_datasets/B/O054.txt
#   inflating: data/bonn_uni_datasets/B/O055.txt
#   inflating: data/bonn_uni_datasets/B/O056.txt
#   inflating: data/bonn_uni_datasets/B/O057.txt
#   inflating: data/bonn_uni_datasets/B/O058.txt
#   inflating: data/bonn_uni_datasets/B/O059.txt
#   inflating: data/bonn_uni_datasets/B/O060.txt
#   inflating: data/bonn_uni_datasets/B/O061.txt
#   inflating: data/bonn_uni_datasets/B/O062.txt
#   inflating: data/bonn_uni_datasets/B/O063.txt
#   inflating: data/bonn_uni_datasets/B/O064.txt
#   inflating: data/bonn_uni_datasets/B/O065.txt
#   inflating: data/bonn_uni_datasets/B/O066.txt
#   inflating: data/bonn_uni_datasets/B/O067.txt
#   inflating: data/bonn_uni_datasets/B/O068.txt
#   inflating: data/bonn_uni_datasets/B/O069.txt
#   inflating: data/bonn_uni_datasets/B/O070.txt
#   inflating: data/bonn_uni_datasets/B/O071.txt
#   inflating: data/bonn_uni_datasets/B/O072.txt
#   inflating: data/bonn_uni_datasets/B/O073.txt
#   inflating: data/bonn_uni_datasets/B/O074.txt
#   inflating: data/bonn_uni_datasets/B/O075.txt
#   inflating: data/bonn_uni_datasets/B/O076.txt
#   inflating: data/bonn_uni_datasets/B/O077.txt
#   inflating: data/bonn_uni_datasets/B/O078.txt
#   inflating: data/bonn_uni_datasets/B/O079.txt
#   inflating: data/bonn_uni_datasets/B/O080.txt
#   inflating: data/bonn_uni_datasets/B/O081.txt
#   inflating: data/bonn_uni_datasets/B/O082.txt
#   inflating: data/bonn_uni_datasets/B/O083.txt
#   inflating: data/bonn_uni_datasets/B/O084.txt
#   inflating: data/bonn_uni_datasets/B/O085.txt
#   inflating: data/bonn_uni_datasets/B/O086.txt
#   inflating: data/bonn_uni_datasets/B/O087.txt
#   inflating: data/bonn_uni_datasets/B/O088.txt
#   inflating: data/bonn_uni_datasets/B/O089.txt
#   inflating: data/bonn_uni_datasets/B/O090.txt
#   inflating: data/bonn_uni_datasets/B/O091.txt
#   inflating: data/bonn_uni_datasets/B/O092.txt
#   inflating: data/bonn_uni_datasets/B/O093.txt
#   inflating: data/bonn_uni_datasets/B/O094.txt
#   inflating: data/bonn_uni_datasets/B/O095.txt
#   inflating: data/bonn_uni_datasets/B/O096.txt
#   inflating: data/bonn_uni_datasets/B/O097.txt
#   inflating: data/bonn_uni_datasets/B/O098.txt
#   inflating: data/bonn_uni_datasets/B/O099.txt
#   inflating: data/bonn_uni_datasets/B/O100.txt
#    creating: data/bonn_uni_datasets/C/
#   inflating: data/bonn_uni_datasets/C/N001.TXT
#   inflating: data/bonn_uni_datasets/C/N002.TXT
#   inflating: data/bonn_uni_datasets/C/N003.TXT
#   inflating: data/bonn_uni_datasets/C/N004.TXT
#   inflating: data/bonn_uni_datasets/C/N005.TXT
#   inflating: data/bonn_uni_datasets/C/N006.TXT
#   inflating: data/bonn_uni_datasets/C/N007.TXT
#   inflating: data/bonn_uni_datasets/C/N008.TXT
#   inflating: data/bonn_uni_datasets/C/N009.TXT
#   inflating: data/bonn_uni_datasets/C/N010.TXT
#   inflating: data/bonn_uni_datasets/C/N011.TXT
#   inflating: data/bonn_uni_datasets/C/N012.TXT
#   inflating: data/bonn_uni_datasets/C/N013.TXT
#   inflating: data/bonn_uni_datasets/C/N014.TXT
#   inflating: data/bonn_uni_datasets/C/N015.TXT
#   inflating: data/bonn_uni_datasets/C/N016.TXT
#   inflating: data/bonn_uni_datasets/C/N017.TXT
#   inflating: data/bonn_uni_datasets/C/N018.TXT
#   inflating: data/bonn_uni_datasets/C/N019.TXT
#   inflating: data/bonn_uni_datasets/C/N020.TXT
#   inflating: data/bonn_uni_datasets/C/N021.TXT
#   inflating: data/bonn_uni_datasets/C/N022.TXT
#   inflating: data/bonn_uni_datasets/C/N023.TXT
#   inflating: data/bonn_uni_datasets/C/N024.TXT
#   inflating: data/bonn_uni_datasets/C/N025.TXT
#   inflating: data/bonn_uni_datasets/C/N026.TXT
#   inflating: data/bonn_uni_datasets/C/N027.TXT
#   inflating: data/bonn_uni_datasets/C/N028.TXT
#   inflating: data/bonn_uni_datasets/C/N029.TXT
#   inflating: data/bonn_uni_datasets/C/N030.TXT
#   inflating: data/bonn_uni_datasets/C/N031.TXT
#   inflating: data/bonn_uni_datasets/C/N032.TXT
#   inflating: data/bonn_uni_datasets/C/N033.TXT
#   inflating: data/bonn_uni_datasets/C/N034.TXT
#   inflating: data/bonn_uni_datasets/C/N035.TXT
#   inflating: data/bonn_uni_datasets/C/N036.TXT
#   inflating: data/bonn_uni_datasets/C/N037.TXT
#   inflating: data/bonn_uni_datasets/C/N038.TXT
#   inflating: data/bonn_uni_datasets/C/N039.TXT
#   inflating: data/bonn_uni_datasets/C/N040.TXT
#   inflating: data/bonn_uni_datasets/C/N041.TXT
#   inflating: data/bonn_uni_datasets/C/N042.TXT
#   inflating: data/bonn_uni_datasets/C/N043.TXT
#   inflating: data/bonn_uni_datasets/C/N044.TXT
#   inflating: data/bonn_uni_datasets/C/N045.TXT
#   inflating: data/bonn_uni_datasets/C/N046.TXT
#   inflating: data/bonn_uni_datasets/C/N047.TXT
#   inflating: data/bonn_uni_datasets/C/N048.TXT
#   inflating: data/bonn_uni_datasets/C/N049.TXT
#   inflating: data/bonn_uni_datasets/C/N050.TXT
#   inflating: data/bonn_uni_datasets/C/N051.TXT
#   inflating: data/bonn_uni_datasets/C/N052.TXT
#   inflating: data/bonn_uni_datasets/C/N053.TXT
#   inflating: data/bonn_uni_datasets/C/N054.TXT
#   inflating: data/bonn_uni_datasets/C/N055.TXT
#   inflating: data/bonn_uni_datasets/C/N056.TXT
#   inflating: data/bonn_uni_datasets/C/N057.TXT
#   inflating: data/bonn_uni_datasets/C/N058.TXT
#   inflating: data/bonn_uni_datasets/C/N059.TXT
#   inflating: data/bonn_uni_datasets/C/N060.TXT
#   inflating: data/bonn_uni_datasets/C/N061.TXT
#   inflating: data/bonn_uni_datasets/C/N062.TXT
#   inflating: data/bonn_uni_datasets/C/N063.TXT
#   inflating: data/bonn_uni_datasets/C/N064.TXT
#   inflating: data/bonn_uni_datasets/C/N065.TXT
#   inflating: data/bonn_uni_datasets/C/N066.TXT
#   inflating: data/bonn_uni_datasets/C/N067.TXT
#   inflating: data/bonn_uni_datasets/C/N068.TXT
#   inflating: data/bonn_uni_datasets/C/N069.TXT
#   inflating: data/bonn_uni_datasets/C/N070.TXT
#   inflating: data/bonn_uni_datasets/C/N071.TXT
#   inflating: data/bonn_uni_datasets/C/N072.TXT
#   inflating: data/bonn_uni_datasets/C/N073.TXT
#   inflating: data/bonn_uni_datasets/C/N074.TXT
#   inflating: data/bonn_uni_datasets/C/N075.TXT
#   inflating: data/bonn_uni_datasets/C/N076.TXT
#   inflating: data/bonn_uni_datasets/C/N077.TXT
#   inflating: data/bonn_uni_datasets/C/N078.TXT
#   inflating: data/bonn_uni_datasets/C/N079.TXT
#   inflating: data/bonn_uni_datasets/C/N080.TXT
#   inflating: data/bonn_uni_datasets/C/N081.TXT
#   inflating: data/bonn_uni_datasets/C/N082.TXT
#   inflating: data/bonn_uni_datasets/C/N083.TXT
#   inflating: data/bonn_uni_datasets/C/N084.TXT
#   inflating: data/bonn_uni_datasets/C/N085.TXT
#   inflating: data/bonn_uni_datasets/C/N086.TXT
#   inflating: data/bonn_uni_datasets/C/N087.TXT
#   inflating: data/bonn_uni_datasets/C/N088.TXT
#   inflating: data/bonn_uni_datasets/C/N089.TXT
#   inflating: data/bonn_uni_datasets/C/N090.TXT
#   inflating: data/bonn_uni_datasets/C/N091.TXT
#   inflating: data/bonn_uni_datasets/C/N092.TXT
#   inflating: data/bonn_uni_datasets/C/N093.TXT
#   inflating: data/bonn_uni_datasets/C/N094.TXT
#   inflating: data/bonn_uni_datasets/C/N095.TXT
#   inflating: data/bonn_uni_datasets/C/N096.TXT
#   inflating: data/bonn_uni_datasets/C/N097.TXT
#   inflating: data/bonn_uni_datasets/C/N098.TXT
#   inflating: data/bonn_uni_datasets/C/N099.TXT
#   inflating: data/bonn_uni_datasets/C/N100.TXT
#    creating: data/bonn_uni_datasets/D/
#   inflating: data/bonn_uni_datasets/D/F001.txt
#   inflating: data/bonn_uni_datasets/D/F002.txt
#   inflating: data/bonn_uni_datasets/D/F003.txt
#   inflating: data/bonn_uni_datasets/D/F004.txt
#   inflating: data/bonn_uni_datasets/D/F005.txt
#   inflating: data/bonn_uni_datasets/D/F006.txt
#   inflating: data/bonn_uni_datasets/D/F007.txt
#   inflating: data/bonn_uni_datasets/D/F008.txt
#   inflating: data/bonn_uni_datasets/D/F009.txt
#   inflating: data/bonn_uni_datasets/D/F010.txt
#   inflating: data/bonn_uni_datasets/D/F011.txt
#   inflating: data/bonn_uni_datasets/D/F012.txt
#   inflating: data/bonn_uni_datasets/D/F013.txt
#   inflating: data/bonn_uni_datasets/D/F014.txt
#   inflating: data/bonn_uni_datasets/D/F015.txt
#   inflating: data/bonn_uni_datasets/D/F016.txt
#   inflating: data/bonn_uni_datasets/D/F017.txt
#   inflating: data/bonn_uni_datasets/D/F018.txt
#   inflating: data/bonn_uni_datasets/D/F019.txt
#   inflating: data/bonn_uni_datasets/D/F020.txt
#   inflating: data/bonn_uni_datasets/D/F021.txt
#   inflating: data/bonn_uni_datasets/D/F022.txt
#   inflating: data/bonn_uni_datasets/D/F023.txt
#   inflating: data/bonn_uni_datasets/D/F024.txt
#   inflating: data/bonn_uni_datasets/D/F025.txt
#   inflating: data/bonn_uni_datasets/D/F026.txt
#   inflating: data/bonn_uni_datasets/D/F027.txt
#   inflating: data/bonn_uni_datasets/D/F028.txt
#   inflating: data/bonn_uni_datasets/D/F029.txt
#   inflating: data/bonn_uni_datasets/D/F030.txt
#   inflating: data/bonn_uni_datasets/D/F031.txt
#   inflating: data/bonn_uni_datasets/D/F032.txt
#   inflating: data/bonn_uni_datasets/D/F033.txt
#   inflating: data/bonn_uni_datasets/D/F034.txt
#   inflating: data/bonn_uni_datasets/D/F035.txt
#   inflating: data/bonn_uni_datasets/D/F036.txt
#   inflating: data/bonn_uni_datasets/D/F037.txt
#   inflating: data/bonn_uni_datasets/D/F038.txt
#   inflating: data/bonn_uni_datasets/D/F039.txt
#   inflating: data/bonn_uni_datasets/D/F040.txt
#   inflating: data/bonn_uni_datasets/D/F041.txt
#   inflating: data/bonn_uni_datasets/D/F042.txt
#   inflating: data/bonn_uni_datasets/D/F043.txt
#   inflating: data/bonn_uni_datasets/D/F044.txt
#   inflating: data/bonn_uni_datasets/D/F045.txt
#   inflating: data/bonn_uni_datasets/D/F046.txt
#   inflating: data/bonn_uni_datasets/D/F047.txt
#   inflating: data/bonn_uni_datasets/D/F048.txt
#   inflating: data/bonn_uni_datasets/D/F049.txt
#   inflating: data/bonn_uni_datasets/D/F050.txt
#   inflating: data/bonn_uni_datasets/D/F051.txt
#   inflating: data/bonn_uni_datasets/D/F052.txt
#   inflating: data/bonn_uni_datasets/D/F053.txt
#   inflating: data/bonn_uni_datasets/D/F054.txt
#   inflating: data/bonn_uni_datasets/D/F055.txt
#   inflating: data/bonn_uni_datasets/D/F056.txt
#   inflating: data/bonn_uni_datasets/D/F057.txt
#   inflating: data/bonn_uni_datasets/D/F058.txt
#   inflating: data/bonn_uni_datasets/D/F059.txt
#   inflating: data/bonn_uni_datasets/D/F060.txt
#   inflating: data/bonn_uni_datasets/D/F061.txt
#   inflating: data/bonn_uni_datasets/D/F062.txt
#   inflating: data/bonn_uni_datasets/D/F063.txt
#   inflating: data/bonn_uni_datasets/D/F064.txt
#   inflating: data/bonn_uni_datasets/D/F065.txt
#   inflating: data/bonn_uni_datasets/D/F066.txt
#   inflating: data/bonn_uni_datasets/D/F067.txt
#   inflating: data/bonn_uni_datasets/D/F068.txt
#   inflating: data/bonn_uni_datasets/D/F069.txt
#   inflating: data/bonn_uni_datasets/D/F070.txt
#   inflating: data/bonn_uni_datasets/D/F071.txt
#   inflating: data/bonn_uni_datasets/D/F072.txt
#   inflating: data/bonn_uni_datasets/D/F073.txt
#   inflating: data/bonn_uni_datasets/D/F074.txt
#   inflating: data/bonn_uni_datasets/D/F075.txt
#   inflating: data/bonn_uni_datasets/D/F076.txt
#   inflating: data/bonn_uni_datasets/D/F077.txt
#   inflating: data/bonn_uni_datasets/D/F078.txt
#   inflating: data/bonn_uni_datasets/D/F079.txt
#   inflating: data/bonn_uni_datasets/D/F080.txt
#   inflating: data/bonn_uni_datasets/D/F081.txt
#   inflating: data/bonn_uni_datasets/D/F082.txt
#   inflating: data/bonn_uni_datasets/D/F083.txt
#   inflating: data/bonn_uni_datasets/D/F084.txt
#   inflating: data/bonn_uni_datasets/D/F085.txt
#   inflating: data/bonn_uni_datasets/D/F086.txt
#   inflating: data/bonn_uni_datasets/D/F087.txt
#   inflating: data/bonn_uni_datasets/D/F088.txt
#   inflating: data/bonn_uni_datasets/D/F089.txt
#   inflating: data/bonn_uni_datasets/D/F090.txt
#   inflating: data/bonn_uni_datasets/D/F091.txt
#   inflating: data/bonn_uni_datasets/D/F092.txt
#   inflating: data/bonn_uni_datasets/D/F093.txt
#   inflating: data/bonn_uni_datasets/D/F094.txt
#   inflating: data/bonn_uni_datasets/D/F095.txt
#   inflating: data/bonn_uni_datasets/D/F096.txt
#   inflating: data/bonn_uni_datasets/D/F097.txt
#   inflating: data/bonn_uni_datasets/D/F098.txt
#   inflating: data/bonn_uni_datasets/D/F099.txt
#   inflating: data/bonn_uni_datasets/D/F100.txt
#    creating: data/bonn_uni_datasets/E/
#   inflating: data/bonn_uni_datasets/E/S001.txt
#   inflating: data/bonn_uni_datasets/E/S002.txt
#   inflating: data/bonn_uni_datasets/E/S003.txt
#   inflating: data/bonn_uni_datasets/E/S004.txt
#   inflating: data/bonn_uni_datasets/E/S005.txt
#   inflating: data/bonn_uni_datasets/E/S006.txt
#   inflating: data/bonn_uni_datasets/E/S007.txt
#   inflating: data/bonn_uni_datasets/E/S008.txt
#   inflating: data/bonn_uni_datasets/E/S009.txt
#   inflating: data/bonn_uni_datasets/E/S010.txt
#   inflating: data/bonn_uni_datasets/E/S011.txt
#   inflating: data/bonn_uni_datasets/E/S012.txt
#   inflating: data/bonn_uni_datasets/E/S013.txt
#   inflating: data/bonn_uni_datasets/E/S014.txt
#   inflating: data/bonn_uni_datasets/E/S015.txt
#   inflating: data/bonn_uni_datasets/E/S016.txt
#   inflating: data/bonn_uni_datasets/E/S017.txt
#   inflating: data/bonn_uni_datasets/E/S018.txt
#   inflating: data/bonn_uni_datasets/E/S019.txt
#   inflating: data/bonn_uni_datasets/E/S020.txt
#   inflating: data/bonn_uni_datasets/E/S021.txt
#   inflating: data/bonn_uni_datasets/E/S022.txt
#   inflating: data/bonn_uni_datasets/E/S023.txt
#   inflating: data/bonn_uni_datasets/E/S024.txt
#   inflating: data/bonn_uni_datasets/E/S025.txt
#   inflating: data/bonn_uni_datasets/E/S026.txt
#   inflating: data/bonn_uni_datasets/E/S027.txt
#   inflating: data/bonn_uni_datasets/E/S028.txt
#   inflating: data/bonn_uni_datasets/E/S029.txt
#   inflating: data/bonn_uni_datasets/E/S030.txt
#   inflating: data/bonn_uni_datasets/E/S031.txt
#   inflating: data/bonn_uni_datasets/E/S032.txt
#   inflating: data/bonn_uni_datasets/E/S033.txt
#   inflating: data/bonn_uni_datasets/E/S034.txt
#   inflating: data/bonn_uni_datasets/E/S035.txt
#   inflating: data/bonn_uni_datasets/E/S036.txt
#   inflating: data/bonn_uni_datasets/E/S037.txt
#   inflating: data/bonn_uni_datasets/E/S038.txt
#   inflating: data/bonn_uni_datasets/E/S039.txt
#   inflating: data/bonn_uni_datasets/E/S040.txt
#   inflating: data/bonn_uni_datasets/E/S041.txt
#   inflating: data/bonn_uni_datasets/E/S042.txt
#   inflating: data/bonn_uni_datasets/E/S043.txt
#   inflating: data/bonn_uni_datasets/E/S044.txt
#   inflating: data/bonn_uni_datasets/E/S045.txt
#   inflating: data/bonn_uni_datasets/E/S046.txt
#   inflating: data/bonn_uni_datasets/E/S047.txt
#   inflating: data/bonn_uni_datasets/E/S048.txt
#   inflating: data/bonn_uni_datasets/E/S049.txt
#   inflating: data/bonn_uni_datasets/E/S050.txt
#   inflating: data/bonn_uni_datasets/E/S051.txt
#   inflating: data/bonn_uni_datasets/E/S052.txt
#   inflating: data/bonn_uni_datasets/E/S053.txt
#   inflating: data/bonn_uni_datasets/E/S054.txt
#   inflating: data/bonn_uni_datasets/E/S055.txt
#   inflating: data/bonn_uni_datasets/E/S056.txt
#   inflating: data/bonn_uni_datasets/E/S057.txt
#   inflating: data/bonn_uni_datasets/E/S058.txt
#   inflating: data/bonn_uni_datasets/E/S059.txt
#   inflating: data/bonn_uni_datasets/E/S060.txt
#   inflating: data/bonn_uni_datasets/E/S061.txt
#   inflating: data/bonn_uni_datasets/E/S062.txt
#   inflating: data/bonn_uni_datasets/E/S063.txt
#   inflating: data/bonn_uni_datasets/E/S064.txt
#   inflating: data/bonn_uni_datasets/E/S065.txt
#   inflating: data/bonn_uni_datasets/E/S066.txt
#   inflating: data/bonn_uni_datasets/E/S067.txt
#   inflating: data/bonn_uni_datasets/E/S068.txt
#   inflating: data/bonn_uni_datasets/E/S069.txt
#   inflating: data/bonn_uni_datasets/E/S070.txt
#   inflating: data/bonn_uni_datasets/E/S071.txt
#   inflating: data/bonn_uni_datasets/E/S072.txt
#   inflating: data/bonn_uni_datasets/E/S073.txt
#   inflating: data/bonn_uni_datasets/E/S074.txt
#   inflating: data/bonn_uni_datasets/E/S075.txt
#   inflating: data/bonn_uni_datasets/E/S076.txt
#   inflating: data/bonn_uni_datasets/E/S077.txt
#   inflating: data/bonn_uni_datasets/E/S078.txt
#   inflating: data/bonn_uni_datasets/E/S079.txt
#   inflating: data/bonn_uni_datasets/E/S080.txt
#   inflating: data/bonn_uni_datasets/E/S081.txt
#   inflating: data/bonn_uni_datasets/E/S082.txt
#   inflating: data/bonn_uni_datasets/E/S083.txt
#   inflating: data/bonn_uni_datasets/E/S084.txt
#   inflating: data/bonn_uni_datasets/E/S085.txt
#   inflating: data/bonn_uni_datasets/E/S086.txt
#   inflating: data/bonn_uni_datasets/E/S087.txt
#   inflating: data/bonn_uni_datasets/E/S088.txt
#   inflating: data/bonn_uni_datasets/E/S089.txt
#   inflating: data/bonn_uni_datasets/E/S090.txt
#   inflating: data/bonn_uni_datasets/E/S091.txt
#   inflating: data/bonn_uni_datasets/E/S092.txt
#   inflating: data/bonn_uni_datasets/E/S093.txt
#   inflating: data/bonn_uni_datasets/E/S094.txt
#   inflating: data/bonn_uni_datasets/E/S095.txt
#   inflating: data/bonn_uni_datasets/E/S096.txt
#   inflating: data/bonn_uni_datasets/E/S097.txt
#   inflating: data/bonn_uni_datasets/E/S098.txt
#   inflating: data/bonn_uni_datasets/E/S099.txt
#   inflating: data/bonn_uni_datasets/E/S100.txt

# %%
def folder_to_df(letter): #import the .txt files
    full_path ="data/bonn_uni_datasets/"+ letter + "/*.*"
    files = files = glob.glob(full_path)
    df_list = []
    for file in files:
        df_list.append(pd.read_csv(file, header = None))
    big_df = pd.concat(df_list, ignore_index=True, axis= 1)
    return big_df.T

def norm(X): # zero mean and unit variance normalization
    X = X - np.mean(X)
    X = X / np.std(X)
    return X

def window(a, w = 512, o = 64, copy = False): #window sliding function
    #default for training, for testing data we will split each signal in four of 1024 and apply
    #a window size of 512 with a stride (o) of 256
    sh = (a.size - w + 1, w)
    st = a.strides * 2
    view = np.lib.stride_tricks.as_strided(a, strides = st, shape = sh)[0::o]
    if copy:
        return view.copy()
    else:
        return view

def enrich_train(df): #enrich data by splicing the 4097-long signals
    #into 512 long ones with a stride of 64
    labels = df.iloc[:,-1]
    data = df.iloc[:, :-1]
    res = list()
    for i in range(len(data)):
        res += [window(data.iloc[i].values)]
    return res

def reshape_x(arr): #shape the input data into the correct form (x1,x2,1)
    nrows = arr.shape[0]
    ncols = arr.shape[1]
    return arr.reshape(nrows, ncols, 1)

# %% [markdown]
# # Load data into dataframes

# %%
def load_data_as_df():
    A = norm(folder_to_df('A'))
    B = norm(folder_to_df('B'))
    C = norm(folder_to_df('C'))
    D = norm(folder_to_df('D'))
    E = norm(folder_to_df('E'))

    normal = A.append(B).reset_index(drop = True)
    interictal = C.append(D).reset_index(drop = True)
    ictal = E

    return normal, interictal, ictal

# %% [markdown]
# # Split into 90%/10%, keeping the 10% for the testing of the majority voting later

# %%
normal, interictal, ictal = load_data_as_df()
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3502: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# <ipython-input-5-4dd2fbd6654e>:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   normal = A.append(B).reset_index(drop = True)
# <ipython-input-5-4dd2fbd6654e>:9: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   interictal = C.append(D).reset_index(drop = True)

# %%
normal_train, normal_vote = train_test_split(normal, test_size = 0.1)
interictal_train, interictal_vote = train_test_split(interictal, test_size = 0.1)
ictal_train, ictal_vote = train_test_split(ictal, test_size = 0.1)

# %% [markdown]
# # Enriching the data as per Scheme 1 in the paper
#
# ### window sliding with a stride of 64 and length of 512, as well as adding labels and format into the correct shape for the model

# %%
def format_enrich_train(normal, interictal, ictal):

    #enrich data and reshape it to have a two dimensional array instead of three
    normal_train_enr = np.asarray(enrich_train(normal)).reshape(-1, np.asarray(enrich_train(normal)).shape[-1])
    interictal_train_enr = np.asarray(enrich_train(interictal)).reshape(-1, np.asarray(enrich_train(interictal)).shape[-1])
    ictal_train_enr = np.asarray(enrich_train(ictal)).reshape(-1, np.asarray(enrich_train(ictal)).shape[-1])

    #change into a dataframe to add labels easily
    normal_train_enr_df = pd.DataFrame(normal_train_enr)
    interictal_train_enr_df = pd.DataFrame(interictal_train_enr)
    ictal_train_enr_df = pd.DataFrame(ictal_train_enr)

    normal_train_enr_df['labels'] = 0 # normal
    interictal_train_enr_df['labels'] = 1 #interictal
    ictal_train_enr_df['labels'] = 2 #ictal

    #concat all
    data_labels = pd.concat([normal_train_enr_df, interictal_train_enr_df, ictal_train_enr_df], ignore_index = True)


    #separates data and labels into numpy arrays for keras
    data = data_labels.drop('labels', axis = 1).values
    labels = data_labels.labels.values

    #labels = np.expand_dims(labels, axis=1)

    return data, labels

# %% [markdown]
# # The model, as per :
# ![Schema of the model](images/model_schema.png)
#
#
# ### Parameters taken in the paper

# %%
def create_model():
    model = Sequential()
    #Conv - 1
    model.add(Conv1D(24, 5,strides =  3, input_shape=(512,1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    #Conv - 2
    model.add(Conv1D(16, 3,strides =  2))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    #Conv - 3
    model.add(Conv1D(8, 3,strides =  2))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    #FC -1
    model.add(Flatten())
    model.add(Dense(20))
    model.add(Activation('relu'))
    #Dropout
    model.add(Dropout(0.5))
    #FC -2
    model.add(Dense(3,activation = 'softmax'))
    #softmax
    #model.add(Activation('softmax'))

    adam = tf.keras.optimizers.legacy.Adam(lr=0.00002, beta_1=0.9, beta_2=0.999, epsilon=0.00000001, decay=0.0, amsgrad=False)

    model.compile(loss='categorical_crossentropy',
                  optimizer=adam,
                  metrics=['accuracy'])
    return model

# %% [markdown]
# # Training function as well as the stratified 10 fold cross validation for testing

# %%
def train_evaluate_model(model, xtrain, ytrain, xval, yval, fold):
    model_name = 'P-1D-CNN'
    metric = 'accuracy'
    checkpointer = ModelCheckpoint(filepath='checkpoints/'+'fold'+ str(fold)+'.'+model_name + '.{epoch:03d}-{accuracy:.3f}.h5',verbose=0, monitor=metric, save_best_only=True)
    history = model.fit(xtrain, ytrain, batch_size=32, callbacks = [checkpointer],epochs=200, verbose = 1)
    print(history)
    score = model.evaluate(xval, yval, batch_size=32)
    print('\n')
    print(score)
    return score, history

# %%
n_folds = 10
X, y = format_enrich_train(normal, interictal, ictal)
#initialize 10 fold validation
skf = StratifiedKFold(n_splits=10, shuffle=True)


#10 fold cross validation loop
for i, (train, test) in enumerate(skf.split(X,y)):
    print("Running Fold", i+1, "/", n_folds)
    start_time = time.time()
    X = reshape_x(X)
    xtrain, xval = X[train], X[test]
    ytrain, yval = y[train], y[test]
    ytrain = to_categorical(ytrain, num_classes=3, dtype='float32')
    yval = to_categorical(yval, num_classes=3, dtype='float32')


    model = None # Clearing the NN.
    model = create_model()
    score, history = train_evaluate_model(model, xtrain, ytrain, xval, yval, i+1)
    print("Ran ", i+1, "/", n_folds, "Fold in %s seconds ---" % (time.time() - start_time))
# Out:
# Running Fold 1 / 10
# /usr/local/lib/python3.10/dist-packages/keras/src/optimizers/legacy/adam.py:118: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/200
# 802/802 [==============================] - 9s 10ms/step - loss: 1.2675 - accuracy: 0.3501
# Epoch 2/200
#  13/802 [..............................] - ETA: 6s - loss: 1.1367 - accuracy: 0.3918
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 802/802 [==============================] - 10s 13ms/step - loss: 1.1226 - accuracy: 0.4013
# Epoch 3/200
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0766 - accuracy: 0.4524
# Epoch 4/200
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0410 - accuracy: 0.4858
# Epoch 5/200
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0090 - accuracy: 0.5167
# Epoch 6/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.9737 - accuracy: 0.5515
# Epoch 7/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9345 - accuracy: 0.5800
# Epoch 8/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9033 - accuracy: 0.6008
# Epoch 9/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.8749 - accuracy: 0.6122
# Epoch 10/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8493 - accuracy: 0.6320
# Epoch 11/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.8235 - accuracy: 0.6426
# Epoch 12/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8040 - accuracy: 0.6569
# Epoch 13/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7792 - accuracy: 0.6705
# Epoch 14/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7529 - accuracy: 0.6841
# Epoch 15/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.7279 - accuracy: 0.6974
# Epoch 16/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7038 - accuracy: 0.7083
# Epoch 17/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.6852 - accuracy: 0.7155
# Epoch 18/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6604 - accuracy: 0.7289
# Epoch 19/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6421 - accuracy: 0.7344
# Epoch 20/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6244 - accuracy: 0.7422
# Epoch 21/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6040 - accuracy: 0.7539
# Epoch 22/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5932 - accuracy: 0.7619
# Epoch 23/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5736 - accuracy: 0.7709
# Epoch 24/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5514 - accuracy: 0.7807
# Epoch 25/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.5449 - accuracy: 0.7847
# Epoch 26/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5313 - accuracy: 0.7966
# Epoch 27/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5233 - accuracy: 0.7968
# Epoch 28/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5090 - accuracy: 0.8055
# Epoch 29/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4988 - accuracy: 0.8108
# Epoch 30/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4918 - accuracy: 0.8151
# Epoch 31/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4782 - accuracy: 0.8216
# Epoch 32/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4700 - accuracy: 0.8243
# Epoch 33/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4688 - accuracy: 0.8254
# Epoch 34/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4555 - accuracy: 0.8303
# Epoch 35/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4492 - accuracy: 0.8325
# Epoch 36/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4457 - accuracy: 0.8350
# Epoch 37/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4421 - accuracy: 0.8396
# Epoch 38/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4340 - accuracy: 0.8434
# Epoch 39/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4224 - accuracy: 0.8472
# Epoch 40/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4200 - accuracy: 0.8501
# Epoch 41/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4102 - accuracy: 0.8530
# Epoch 42/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4043 - accuracy: 0.8532
# Epoch 43/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4081 - accuracy: 0.8533
# Epoch 44/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4010 - accuracy: 0.8570
# Epoch 45/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3936 - accuracy: 0.8599
# Epoch 46/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3888 - accuracy: 0.8586
# Epoch 47/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3819 - accuracy: 0.8654
# Epoch 48/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3741 - accuracy: 0.8670
# Epoch 49/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3774 - accuracy: 0.8644
# Epoch 50/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3711 - accuracy: 0.8674
# Epoch 51/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3751 - accuracy: 0.8681
# Epoch 52/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3580 - accuracy: 0.8744
# Epoch 53/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3628 - accuracy: 0.8729
# Epoch 54/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3619 - accuracy: 0.8712
# Epoch 55/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3536 - accuracy: 0.8750
# Epoch 56/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3502 - accuracy: 0.8757
# Epoch 57/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3438 - accuracy: 0.8786
# Epoch 58/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3486 - accuracy: 0.8775
# Epoch 59/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3414 - accuracy: 0.8786
# Epoch 60/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3332 - accuracy: 0.8818
# Epoch 61/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3352 - accuracy: 0.8832
# Epoch 62/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3304 - accuracy: 0.8853
# Epoch 63/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3231 - accuracy: 0.8857
# Epoch 64/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3262 - accuracy: 0.8841
# Epoch 65/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3208 - accuracy: 0.8876
# Epoch 66/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3146 - accuracy: 0.8915
# Epoch 67/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3127 - accuracy: 0.8917
# Epoch 68/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.3064 - accuracy: 0.8926
# Epoch 69/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3031 - accuracy: 0.8949
# Epoch 70/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3075 - accuracy: 0.8927
# Epoch 71/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2966 - accuracy: 0.8956
# Epoch 72/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2996 - accuracy: 0.8958
# Epoch 73/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.2924 - accuracy: 0.8982
# Epoch 74/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2913 - accuracy: 0.8982
# Epoch 75/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2875 - accuracy: 0.8993
# Epoch 76/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2918 - accuracy: 0.8994
# Epoch 77/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2840 - accuracy: 0.9028
# Epoch 78/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2852 - accuracy: 0.9000
# Epoch 79/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2762 - accuracy: 0.9043
# Epoch 80/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2791 - accuracy: 0.9028
# Epoch 81/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2710 - accuracy: 0.9072
# Epoch 82/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2701 - accuracy: 0.9080
# Epoch 83/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.2715 - accuracy: 0.9065
# Epoch 84/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2690 - accuracy: 0.9074
# Epoch 85/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2641 - accuracy: 0.9083
# Epoch 86/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2582 - accuracy: 0.9100
# Epoch 87/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2627 - accuracy: 0.9094
# Epoch 88/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2613 - accuracy: 0.9081
# Epoch 89/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2524 - accuracy: 0.9126
# Epoch 90/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2531 - accuracy: 0.9143
# Epoch 91/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2544 - accuracy: 0.9146
# Epoch 92/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2422 - accuracy: 0.9164
# Epoch 93/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.2475 - accuracy: 0.9144
# Epoch 94/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2412 - accuracy: 0.9184
# Epoch 95/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2393 - accuracy: 0.9186
# Epoch 96/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2380 - accuracy: 0.9193
# Epoch 97/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2372 - accuracy: 0.9176
# Epoch 98/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.2400 - accuracy: 0.9185
# Epoch 99/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2312 - accuracy: 0.9205
# Epoch 100/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2319 - accuracy: 0.9202
# Epoch 101/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2362 - accuracy: 0.9196
# Epoch 102/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2293 - accuracy: 0.9226
# Epoch 103/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2256 - accuracy: 0.9239
# Epoch 104/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2308 - accuracy: 0.9203
# Epoch 105/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2268 - accuracy: 0.9224
# Epoch 106/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2226 - accuracy: 0.9241
# Epoch 107/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2220 - accuracy: 0.9241
# Epoch 108/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2178 - accuracy: 0.9252
# Epoch 109/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2219 - accuracy: 0.9247
# Epoch 110/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2101 - accuracy: 0.9290
# Epoch 111/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2187 - accuracy: 0.9256
# Epoch 112/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2122 - accuracy: 0.9296
# Epoch 113/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2144 - accuracy: 0.9283
# Epoch 114/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2143 - accuracy: 0.9272
# Epoch 115/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2120 - accuracy: 0.9278
# Epoch 116/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2098 - accuracy: 0.9303
# Epoch 117/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2107 - accuracy: 0.9284
# Epoch 118/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2019 - accuracy: 0.9308
# Epoch 119/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2059 - accuracy: 0.9311
# Epoch 120/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2085 - accuracy: 0.9288
# Epoch 121/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2080 - accuracy: 0.9278
# Epoch 122/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2012 - accuracy: 0.9328
# Epoch 123/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2028 - accuracy: 0.9310
# Epoch 124/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1998 - accuracy: 0.9320
# Epoch 125/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2042 - accuracy: 0.9303
# Epoch 126/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2023 - accuracy: 0.9313
# Epoch 127/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1937 - accuracy: 0.9349
# Epoch 128/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1949 - accuracy: 0.9336
# Epoch 129/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1930 - accuracy: 0.9353
# Epoch 130/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1947 - accuracy: 0.9342
# Epoch 131/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1966 - accuracy: 0.9342
# Epoch 132/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1907 - accuracy: 0.9370
# Epoch 133/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1931 - accuracy: 0.9356
# Epoch 134/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1919 - accuracy: 0.9352
# Epoch 135/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1883 - accuracy: 0.9360
# Epoch 136/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1874 - accuracy: 0.9377
# Epoch 137/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1914 - accuracy: 0.9362
# Epoch 138/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1839 - accuracy: 0.9377
# Epoch 139/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1855 - accuracy: 0.9381
# Epoch 140/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1792 - accuracy: 0.9384
# Epoch 141/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1853 - accuracy: 0.9379
# Epoch 142/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1795 - accuracy: 0.9382
# Epoch 143/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1832 - accuracy: 0.9383
# Epoch 144/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1767 - accuracy: 0.9423
# Epoch 145/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1806 - accuracy: 0.9399
# Epoch 146/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1807 - accuracy: 0.9389
# Epoch 147/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1763 - accuracy: 0.9412
# Epoch 148/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1818 - accuracy: 0.9389
# Epoch 149/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1827 - accuracy: 0.9395
# Epoch 150/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1773 - accuracy: 0.9415
# Epoch 151/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1750 - accuracy: 0.9421
# Epoch 152/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1749 - accuracy: 0.9430
# Epoch 153/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1720 - accuracy: 0.9422
# Epoch 154/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1736 - accuracy: 0.9411
# Epoch 155/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1700 - accuracy: 0.9438
# Epoch 156/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1685 - accuracy: 0.9424
# Epoch 157/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1715 - accuracy: 0.9441
# Epoch 158/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1700 - accuracy: 0.9408
# Epoch 159/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1712 - accuracy: 0.9413
# Epoch 160/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1662 - accuracy: 0.9439
# Epoch 161/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1687 - accuracy: 0.9439
# Epoch 162/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1638 - accuracy: 0.9446
# Epoch 163/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1652 - accuracy: 0.9446
# Epoch 164/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1635 - accuracy: 0.9446
# Epoch 165/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1644 - accuracy: 0.9432
# Epoch 166/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1653 - accuracy: 0.9449
# Epoch 167/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1620 - accuracy: 0.9458
# Epoch 168/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1646 - accuracy: 0.9451
# Epoch 169/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1675 - accuracy: 0.9446
# Epoch 170/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1655 - accuracy: 0.9454
# Epoch 171/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1594 - accuracy: 0.9472
# Epoch 172/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1608 - accuracy: 0.9464
# Epoch 173/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1546 - accuracy: 0.9486
# Epoch 174/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1584 - accuracy: 0.9481
# Epoch 175/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1559 - accuracy: 0.9478
# Epoch 176/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1559 - accuracy: 0.9481
# Epoch 177/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1536 - accuracy: 0.9499
# Epoch 178/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1592 - accuracy: 0.9461
# Epoch 179/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1616 - accuracy: 0.9464
# Epoch 180/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1576 - accuracy: 0.9487
# Epoch 181/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1535 - accuracy: 0.9485
# Epoch 182/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1548 - accuracy: 0.9488
# Epoch 183/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1593 - accuracy: 0.9454
# Epoch 184/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1559 - accuracy: 0.9467
# Epoch 185/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1523 - accuracy: 0.9500
# Epoch 186/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1537 - accuracy: 0.9497
# Epoch 187/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1503 - accuracy: 0.9510
# Epoch 188/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1499 - accuracy: 0.9503
# Epoch 189/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1494 - accuracy: 0.9487
# Epoch 190/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1525 - accuracy: 0.9504
# Epoch 191/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1565 - accuracy: 0.9474
# Epoch 192/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1481 - accuracy: 0.9505
# Epoch 193/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1463 - accuracy: 0.9525
# Epoch 194/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1482 - accuracy: 0.9499
# Epoch 195/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1455 - accuracy: 0.9522
# Epoch 196/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1452 - accuracy: 0.9535
# Epoch 197/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1459 - accuracy: 0.9513
# Epoch 198/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1435 - accuracy: 0.9526
# Epoch 199/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1472 - accuracy: 0.9496
# Epoch 200/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1458 - accuracy: 0.9518
# <keras.src.callbacks.History object at 0x7c9ae40ceb30>
# 90/90 [==============================] - 1s 4ms/step - loss: 0.0737 - accuracy: 0.9758
#
#
# [0.0737466961145401, 0.975789487361908]
# Ran  1 / 10 Fold in 1584.3678500652313 seconds ---
# Running Fold 2 / 10
# Epoch 1/200
# 802/802 [==============================] - 9s 10ms/step - loss: 1.2455 - accuracy: 0.3666
# Epoch 2/200
# 802/802 [==============================] - 7s 9ms/step - loss: 1.0908 - accuracy: 0.4739
# Epoch 3/200
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0137 - accuracy: 0.5408
# Epoch 4/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9367 - accuracy: 0.6011
# Epoch 5/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.8828 - accuracy: 0.6376
# Epoch 6/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8496 - accuracy: 0.6568
# Epoch 7/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.8188 - accuracy: 0.6717
# Epoch 8/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7930 - accuracy: 0.6840
# Epoch 9/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7768 - accuracy: 0.6906
# Epoch 10/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7603 - accuracy: 0.6965
# Epoch 11/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7422 - accuracy: 0.7033
# Epoch 12/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.7277 - accuracy: 0.7076
# Epoch 13/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.7148 - accuracy: 0.7127
# Epoch 14/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7008 - accuracy: 0.7163
# Epoch 15/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6870 - accuracy: 0.7212
# Epoch 16/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6700 - accuracy: 0.7262
# Epoch 17/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6551 - accuracy: 0.7301
# Epoch 18/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6447 - accuracy: 0.7377
# Epoch 19/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6246 - accuracy: 0.7414
# Epoch 20/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6098 - accuracy: 0.7512
# Epoch 21/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5936 - accuracy: 0.7569
# Epoch 22/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5831 - accuracy: 0.7607
# Epoch 23/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5654 - accuracy: 0.7712
# Epoch 24/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5556 - accuracy: 0.7706
# Epoch 25/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5387 - accuracy: 0.7786
# Epoch 26/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5230 - accuracy: 0.7895
# Epoch 27/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5127 - accuracy: 0.7929
# Epoch 28/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5031 - accuracy: 0.8011
# Epoch 29/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4886 - accuracy: 0.8064
# Epoch 30/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4863 - accuracy: 0.8082
# Epoch 31/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4644 - accuracy: 0.8176
# Epoch 32/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4543 - accuracy: 0.8234
# Epoch 33/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4567 - accuracy: 0.8218
# Epoch 34/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4464 - accuracy: 0.8285
# Epoch 35/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4380 - accuracy: 0.8298
# Epoch 36/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4265 - accuracy: 0.8349
# Epoch 37/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4197 - accuracy: 0.8377
# Epoch 38/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4181 - accuracy: 0.8415
# Epoch 39/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4050 - accuracy: 0.8463
# Epoch 40/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4012 - accuracy: 0.8465
# Epoch 41/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3995 - accuracy: 0.8476
# Epoch 42/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3915 - accuracy: 0.8551
# Epoch 43/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3861 - accuracy: 0.8546
# Epoch 44/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.3756 - accuracy: 0.8594
# Epoch 45/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3830 - accuracy: 0.8570
# Epoch 46/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3751 - accuracy: 0.8601
# Epoch 47/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3711 - accuracy: 0.8644
# Epoch 48/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3661 - accuracy: 0.8619
# Epoch 49/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3595 - accuracy: 0.8666
# Epoch 50/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3504 - accuracy: 0.8714
# Epoch 51/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3508 - accuracy: 0.8680
# Epoch 52/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3402 - accuracy: 0.8738
# Epoch 53/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3349 - accuracy: 0.8782
# Epoch 54/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3311 - accuracy: 0.8793
# Epoch 55/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3304 - accuracy: 0.8803
# Epoch 56/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3223 - accuracy: 0.8819
# Epoch 57/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3174 - accuracy: 0.8859
# Epoch 58/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3179 - accuracy: 0.8822
# Epoch 59/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3056 - accuracy: 0.8891
# Epoch 60/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3030 - accuracy: 0.8885
# Epoch 61/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2967 - accuracy: 0.8941
# Epoch 62/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2915 - accuracy: 0.8958
# Epoch 63/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2928 - accuracy: 0.8954
# Epoch 64/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2859 - accuracy: 0.8980
# Epoch 65/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2841 - accuracy: 0.8986
# Epoch 66/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2796 - accuracy: 0.8995
# Epoch 67/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2812 - accuracy: 0.9000
# Epoch 68/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2724 - accuracy: 0.9004
# Epoch 69/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2709 - accuracy: 0.9040
# Epoch 70/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2583 - accuracy: 0.9104
# Epoch 71/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2583 - accuracy: 0.9083
# Epoch 72/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2535 - accuracy: 0.9133
# Epoch 73/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2510 - accuracy: 0.9117
# Epoch 74/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2489 - accuracy: 0.9122
# Epoch 75/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2487 - accuracy: 0.9116
# Epoch 76/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2417 - accuracy: 0.9166
# Epoch 77/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.2457 - accuracy: 0.9145
# Epoch 78/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2399 - accuracy: 0.9164
# Epoch 79/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2374 - accuracy: 0.9179
# Epoch 80/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2283 - accuracy: 0.9208
# Epoch 81/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2252 - accuracy: 0.9219
# Epoch 82/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2271 - accuracy: 0.9222
# Epoch 83/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2253 - accuracy: 0.9194
# Epoch 84/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2233 - accuracy: 0.9245
# Epoch 85/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2170 - accuracy: 0.9274
# Epoch 86/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2190 - accuracy: 0.9248
# Epoch 87/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2142 - accuracy: 0.9263
# Epoch 88/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2131 - accuracy: 0.9264
# Epoch 89/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2100 - accuracy: 0.9267
# Epoch 90/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.2072 - accuracy: 0.9303
# Epoch 91/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2058 - accuracy: 0.9308
# Epoch 92/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2077 - accuracy: 0.9290
# Epoch 93/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.2049 - accuracy: 0.9310
# Epoch 94/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2046 - accuracy: 0.9309
# Epoch 95/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1990 - accuracy: 0.9332
# Epoch 96/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2002 - accuracy: 0.9333
# Epoch 97/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1952 - accuracy: 0.9336
# Epoch 98/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1946 - accuracy: 0.9345
# Epoch 99/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1892 - accuracy: 0.9350
# Epoch 100/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1948 - accuracy: 0.9333
# Epoch 101/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1934 - accuracy: 0.9344
# Epoch 102/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1885 - accuracy: 0.9379
# Epoch 103/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1864 - accuracy: 0.9356
# Epoch 104/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1834 - accuracy: 0.9383
# Epoch 105/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1791 - accuracy: 0.9404
# Epoch 106/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1803 - accuracy: 0.9388
# Epoch 107/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1844 - accuracy: 0.9396
# Epoch 108/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1815 - accuracy: 0.9377
# Epoch 109/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1753 - accuracy: 0.9420
# Epoch 110/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1777 - accuracy: 0.9394
# Epoch 111/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1758 - accuracy: 0.9414
# Epoch 112/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1725 - accuracy: 0.9424
# Epoch 113/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1730 - accuracy: 0.9423
# Epoch 114/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1680 - accuracy: 0.9425
# Epoch 115/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1665 - accuracy: 0.9435
# Epoch 116/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1716 - accuracy: 0.9425
# Epoch 117/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1649 - accuracy: 0.9442
# Epoch 118/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1626 - accuracy: 0.9441
# Epoch 119/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1674 - accuracy: 0.9434
# Epoch 120/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1704 - accuracy: 0.9422
# Epoch 121/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1605 - accuracy: 0.9467
# Epoch 122/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1595 - accuracy: 0.9471
# Epoch 123/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1602 - accuracy: 0.9471
# Epoch 124/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1580 - accuracy: 0.9466
# Epoch 125/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1604 - accuracy: 0.9450
# Epoch 126/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1574 - accuracy: 0.9460
# Epoch 127/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1576 - accuracy: 0.9464
# Epoch 128/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1602 - accuracy: 0.9465
# Epoch 129/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1557 - accuracy: 0.9484
# Epoch 130/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1543 - accuracy: 0.9476
# Epoch 131/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1532 - accuracy: 0.9501
# Epoch 132/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1480 - accuracy: 0.9520
# Epoch 133/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1550 - accuracy: 0.9487
# Epoch 134/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1530 - accuracy: 0.9496
# Epoch 135/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1456 - accuracy: 0.9519
# Epoch 136/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1463 - accuracy: 0.9512
# Epoch 137/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1494 - accuracy: 0.9496
# Epoch 138/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1495 - accuracy: 0.9503
# Epoch 139/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1530 - accuracy: 0.9483
# Epoch 140/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1480 - accuracy: 0.9521
# Epoch 141/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1510 - accuracy: 0.9499
# Epoch 142/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1507 - accuracy: 0.9505
# Epoch 143/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1491 - accuracy: 0.9512
# Epoch 144/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1417 - accuracy: 0.9523
# Epoch 145/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1432 - accuracy: 0.9530
# Epoch 146/200
# 802/802 [==============================] - 9s 12ms/step - loss: 0.1407 - accuracy: 0.9534
# Epoch 147/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1379 - accuracy: 0.9537
# Epoch 148/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1429 - accuracy: 0.9525
# Epoch 149/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1439 - accuracy: 0.9514
# Epoch 150/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1345 - accuracy: 0.9552
# Epoch 151/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1383 - accuracy: 0.9539
# Epoch 152/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1381 - accuracy: 0.9538
# Epoch 153/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1385 - accuracy: 0.9541
# Epoch 154/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1389 - accuracy: 0.9535
# Epoch 155/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1403 - accuracy: 0.9539
# Epoch 156/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1372 - accuracy: 0.9557
# Epoch 157/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1361 - accuracy: 0.9537
# Epoch 158/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1316 - accuracy: 0.9559
# Epoch 159/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1367 - accuracy: 0.9527
# Epoch 160/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1328 - accuracy: 0.9558
# Epoch 161/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1320 - accuracy: 0.9557
# Epoch 162/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1322 - accuracy: 0.9554
# Epoch 163/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1316 - accuracy: 0.9559
# Epoch 164/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1279 - accuracy: 0.9558
# Epoch 165/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1314 - accuracy: 0.9555
# Epoch 166/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1270 - accuracy: 0.9578
# Epoch 167/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1359 - accuracy: 0.9542
# Epoch 168/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1253 - accuracy: 0.9570
# Epoch 169/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1289 - accuracy: 0.9575
# Epoch 170/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1308 - accuracy: 0.9557
# Epoch 171/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1266 - accuracy: 0.9573
# Epoch 172/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1276 - accuracy: 0.9583
# Epoch 173/200
# 802/802 [==============================] - 9s 12ms/step - loss: 0.1283 - accuracy: 0.9571
# Epoch 174/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.1221 - accuracy: 0.9591
# Epoch 175/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1231 - accuracy: 0.9591
# Epoch 176/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1261 - accuracy: 0.9580
# Epoch 177/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1232 - accuracy: 0.9586
# Epoch 178/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1244 - accuracy: 0.9582
# Epoch 179/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1250 - accuracy: 0.9589
# Epoch 180/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1245 - accuracy: 0.9578
# Epoch 181/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1229 - accuracy: 0.9584
# Epoch 182/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1238 - accuracy: 0.9589
# Epoch 183/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1187 - accuracy: 0.9604
# Epoch 184/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1235 - accuracy: 0.9593
# Epoch 185/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1221 - accuracy: 0.9581
# Epoch 186/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1210 - accuracy: 0.9604
# Epoch 187/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.1184 - accuracy: 0.9597
# Epoch 188/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1198 - accuracy: 0.9610
# Epoch 189/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1248 - accuracy: 0.9598
# Epoch 190/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1199 - accuracy: 0.9574
# Epoch 191/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1225 - accuracy: 0.9579
# Epoch 192/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1197 - accuracy: 0.9600
# Epoch 193/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1170 - accuracy: 0.9609
# Epoch 194/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1172 - accuracy: 0.9614
# Epoch 195/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1166 - accuracy: 0.9605
# Epoch 196/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.1207 - accuracy: 0.9589
# Epoch 197/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1180 - accuracy: 0.9595
# Epoch 198/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.1184 - accuracy: 0.9601
# Epoch 199/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.1168 - accuracy: 0.9611
# Epoch 200/200
# 802/802 [==============================] - 9s 12ms/step - loss: 0.1158 - accuracy: 0.9614
# <keras.src.callbacks.History object at 0x7c9ad6d669e0>
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0542 - accuracy: 0.9825
#
#
# [0.054169632494449615, 0.9824561476707458]
# Ran  2 / 10 Fold in 1606.096599817276 seconds ---
# Running Fold 3 / 10
# Epoch 1/200
# 802/802 [==============================] - 10s 11ms/step - loss: 1.2241 - accuracy: 0.3250
# Epoch 2/200
# 802/802 [==============================] - 9s 11ms/step - loss: 1.1037 - accuracy: 0.4242
# Epoch 3/200
# 802/802 [==============================] - 8s 10ms/step - loss: 1.0588 - accuracy: 0.4912
# Epoch 4/200
# 802/802 [==============================] - 9s 11ms/step - loss: 1.0107 - accuracy: 0.5276
# Epoch 5/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9619 - accuracy: 0.5683
# Epoch 6/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.9180 - accuracy: 0.5924
# Epoch 7/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8875 - accuracy: 0.6101
# Epoch 8/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.8598 - accuracy: 0.6314
# Epoch 9/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.8358 - accuracy: 0.6410
# Epoch 10/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.8186 - accuracy: 0.6542
# Epoch 11/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7987 - accuracy: 0.6674
# Epoch 12/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7873 - accuracy: 0.6690
# Epoch 13/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.7719 - accuracy: 0.6772
# Epoch 14/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7622 - accuracy: 0.6817
# Epoch 15/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7480 - accuracy: 0.6866
# Epoch 16/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7306 - accuracy: 0.6952
# Epoch 17/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7209 - accuracy: 0.7001
# Epoch 18/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.7103 - accuracy: 0.7065
# Epoch 19/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6936 - accuracy: 0.7117
# Epoch 20/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6838 - accuracy: 0.7153
# Epoch 21/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6704 - accuracy: 0.7205
# Epoch 22/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6604 - accuracy: 0.7273
# Epoch 23/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6488 - accuracy: 0.7304
# Epoch 24/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6302 - accuracy: 0.7383
# Epoch 25/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.6216 - accuracy: 0.7432
# Epoch 26/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.6062 - accuracy: 0.7523
# Epoch 27/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.5920 - accuracy: 0.7578
# Epoch 28/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5807 - accuracy: 0.7634
# Epoch 29/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5609 - accuracy: 0.7736
# Epoch 30/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.5458 - accuracy: 0.7828
# Epoch 31/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.5359 - accuracy: 0.7913
# Epoch 32/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5177 - accuracy: 0.7991
# Epoch 33/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.5037 - accuracy: 0.8044
# Epoch 34/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4941 - accuracy: 0.8103
# Epoch 35/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.4749 - accuracy: 0.8180
# Epoch 36/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.4609 - accuracy: 0.8264
# Epoch 37/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.4547 - accuracy: 0.8315
# Epoch 38/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.4337 - accuracy: 0.8398
# Epoch 39/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.4236 - accuracy: 0.8453
# Epoch 40/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4069 - accuracy: 0.8526
# Epoch 41/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.3990 - accuracy: 0.8547
# Epoch 42/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3814 - accuracy: 0.8604
# Epoch 43/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3774 - accuracy: 0.8639
# Epoch 44/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.3676 - accuracy: 0.8655
# Epoch 45/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.3630 - accuracy: 0.8702
# Epoch 46/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.3504 - accuracy: 0.8749
# Epoch 47/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3471 - accuracy: 0.8763
# Epoch 48/200
# 802/802 [==============================] - 8s 9ms/step - loss: 0.3328 - accuracy: 0.8836
# Epoch 49/200
# 802/802 [==============================] - 9s 11ms/step - loss: 0.3371 - accuracy: 0.8787
# Epoch 50/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.3282 - accuracy: 0.8838
# Epoch 51/200
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3237 - accuracy: 0.8857
# Epoch 52/200
# 802/802 [==============================] - 8s 11ms/step - loss: 0.3158 - accuracy: 0.8880
# Epoch 53/200
# 802/802 [==============================] - 9s 12ms/step - loss: 0.3050 - accuracy: 0.8913
# Epoch 54/200
# 802/802 [==============================] - 8s 10ms/step - loss: 0.2996 - accuracy: 0.8941
# Epoch 55/200
# ...
# Epoch 51/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3786 - accuracy: 0.8568
# Epoch 52/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3759 - accuracy: 0.8575
# Epoch 53/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.3692 - accuracy: 0.8595
# Epoch 54/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3751 - accuracy: 0.8595
# Epoch 55/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3539 - accuracy: 0.8669
# Epoch 56/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.3480 - accuracy: 0.8678
# Epoch 57/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.3481 - accuracy: 0.8700
# Epoch 58/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3463 - accuracy: 0.8704
# Epoch 59/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.3393 - accuracy: 0.8726
# Epoch 60/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.3414 - accuracy: 0.8701
# Epoch 61/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3339 - accuracy: 0.8753
# Epoch 62/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3302 - accuracy: 0.8764
# Epoch 63/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.3209 - accuracy: 0.8826
# Epoch 64/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3226 - accuracy: 0.8802
# Epoch 65/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.3201 - accuracy: 0.8813
# Epoch 66/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.3119 - accuracy: 0.8842
# Epoch 67/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.3109 - accuracy: 0.8857
# Epoch 68/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.3033 - accuracy: 0.8870
# Epoch 69/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.3061 - accuracy: 0.8845
# Epoch 70/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.3046 - accuracy: 0.8862
# Epoch 71/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2949 - accuracy: 0.8897
# Epoch 72/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2918 - accuracy: 0.8923
# Epoch 73/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2882 - accuracy: 0.8942
# Epoch 74/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2870 - accuracy: 0.8948
# Epoch 75/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2755 - accuracy: 0.8991
# Epoch 76/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2802 - accuracy: 0.8989
# Epoch 77/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.2765 - accuracy: 0.9004
# Epoch 78/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2741 - accuracy: 0.9021
# Epoch 79/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2671 - accuracy: 0.9019
# Epoch 80/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.2663 - accuracy: 0.9044
# Epoch 81/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2588 - accuracy: 0.9085
# Epoch 82/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2578 - accuracy: 0.9091
# Epoch 83/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.2531 - accuracy: 0.9120
# Epoch 84/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2562 - accuracy: 0.9101
# Epoch 85/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2476 - accuracy: 0.9131
# Epoch 86/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2443 - accuracy: 0.9140
# Epoch 87/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.2426 - accuracy: 0.9148
# Epoch 88/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2384 - accuracy: 0.9155
# Epoch 89/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.2400 - accuracy: 0.9170
# Epoch 90/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2367 - accuracy: 0.9182
# Epoch 91/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.2371 - accuracy: 0.9167
# Epoch 92/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2331 - accuracy: 0.9195
# Epoch 93/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2297 - accuracy: 0.9189
# Epoch 94/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.2273 - accuracy: 0.9200
# Epoch 95/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2252 - accuracy: 0.9216
# Epoch 96/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2211 - accuracy: 0.9236
# Epoch 97/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2218 - accuracy: 0.9233
# Epoch 98/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2187 - accuracy: 0.9227
# Epoch 99/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2203 - accuracy: 0.9239
# Epoch 100/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.2148 - accuracy: 0.9258
# Epoch 101/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.2148 - accuracy: 0.9264
# Epoch 102/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.2119 - accuracy: 0.9260
# Epoch 103/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2039 - accuracy: 0.9302
# Epoch 104/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.2125 - accuracy: 0.9275
# Epoch 105/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2044 - accuracy: 0.9287
# Epoch 106/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2033 - accuracy: 0.9298
# Epoch 107/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.2026 - accuracy: 0.9305
# Epoch 108/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1998 - accuracy: 0.9306
# Epoch 109/200
# 802/802 [==============================] - 13s 16ms/step - loss: 0.2005 - accuracy: 0.9302
# Epoch 110/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1935 - accuracy: 0.9328
# Epoch 111/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1962 - accuracy: 0.9335
# Epoch 112/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1924 - accuracy: 0.9344
# Epoch 113/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1930 - accuracy: 0.9345
# Epoch 114/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1861 - accuracy: 0.9365
# Epoch 115/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1887 - accuracy: 0.9342
# Epoch 116/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1858 - accuracy: 0.9352
# Epoch 117/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1867 - accuracy: 0.9356
# Epoch 118/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1781 - accuracy: 0.9414
# Epoch 119/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1804 - accuracy: 0.9396
# Epoch 120/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1792 - accuracy: 0.9390
# Epoch 121/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1826 - accuracy: 0.9388
# Epoch 122/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1782 - accuracy: 0.9399
# Epoch 123/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1777 - accuracy: 0.9398
# Epoch 124/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1775 - accuracy: 0.9390
# Epoch 125/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1725 - accuracy: 0.9423
# Epoch 126/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1757 - accuracy: 0.9404
# Epoch 127/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1768 - accuracy: 0.9404
# Epoch 128/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1701 - accuracy: 0.9415
# Epoch 129/200
# 802/802 [==============================] - 13s 16ms/step - loss: 0.1699 - accuracy: 0.9413
# Epoch 130/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1709 - accuracy: 0.9421
# Epoch 131/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1701 - accuracy: 0.9401
# Epoch 132/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1647 - accuracy: 0.9449
# Epoch 133/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1652 - accuracy: 0.9433
# Epoch 134/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1672 - accuracy: 0.9441
# Epoch 135/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1609 - accuracy: 0.9457
# Epoch 136/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1604 - accuracy: 0.9449
# Epoch 137/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1568 - accuracy: 0.9483
# Epoch 138/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1567 - accuracy: 0.9474
# Epoch 139/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1573 - accuracy: 0.9456
# Epoch 140/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.1597 - accuracy: 0.9454
# Epoch 141/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1557 - accuracy: 0.9466
# Epoch 142/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1568 - accuracy: 0.9468
# Epoch 143/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1601 - accuracy: 0.9475
# Epoch 144/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1515 - accuracy: 0.9494
# Epoch 145/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1610 - accuracy: 0.9460
# Epoch 146/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1520 - accuracy: 0.9485
# Epoch 147/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1499 - accuracy: 0.9500
# Epoch 148/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1499 - accuracy: 0.9484
# Epoch 149/200
# 802/802 [==============================] - 13s 16ms/step - loss: 0.1509 - accuracy: 0.9495
# Epoch 150/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1442 - accuracy: 0.9526
# Epoch 151/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1427 - accuracy: 0.9522
# Epoch 152/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1443 - accuracy: 0.9517
# Epoch 153/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1433 - accuracy: 0.9516
# Epoch 154/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1465 - accuracy: 0.9517
# Epoch 155/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1485 - accuracy: 0.9501
# Epoch 156/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1478 - accuracy: 0.9508
# Epoch 157/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1451 - accuracy: 0.9508
# Epoch 158/200
# 802/802 [==============================] - 10s 12ms/step - loss: 0.1440 - accuracy: 0.9525
# Epoch 159/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1396 - accuracy: 0.9528
# Epoch 160/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1456 - accuracy: 0.9519
# Epoch 161/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1404 - accuracy: 0.9527
# Epoch 162/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1472 - accuracy: 0.9504
# Epoch 163/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1394 - accuracy: 0.9544
# Epoch 164/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1386 - accuracy: 0.9541
# Epoch 165/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1411 - accuracy: 0.9528
# Epoch 166/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1373 - accuracy: 0.9559
# Epoch 167/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1408 - accuracy: 0.9523
# Epoch 168/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1400 - accuracy: 0.9531
# Epoch 169/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.1376 - accuracy: 0.9536
# Epoch 170/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1366 - accuracy: 0.9537
# Epoch 171/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1357 - accuracy: 0.9544
# Epoch 172/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1333 - accuracy: 0.9541
# Epoch 173/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1328 - accuracy: 0.9552
# Epoch 174/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1335 - accuracy: 0.9549
# Epoch 175/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1313 - accuracy: 0.9565
# Epoch 176/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1323 - accuracy: 0.9550
# Epoch 177/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1306 - accuracy: 0.9565
# Epoch 178/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1355 - accuracy: 0.9533
# Epoch 179/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1300 - accuracy: 0.9575
# Epoch 180/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1338 - accuracy: 0.9565
# Epoch 181/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1309 - accuracy: 0.9551
# Epoch 182/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1318 - accuracy: 0.9564
# Epoch 183/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1247 - accuracy: 0.9577
# Epoch 184/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1317 - accuracy: 0.9561
# Epoch 185/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1272 - accuracy: 0.9566
# Epoch 186/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1325 - accuracy: 0.9558
# Epoch 187/200
# 802/802 [==============================] - 10s 13ms/step - loss: 0.1261 - accuracy: 0.9577
# Epoch 188/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1274 - accuracy: 0.9565
# Epoch 189/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.1249 - accuracy: 0.9577
# Epoch 190/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.1262 - accuracy: 0.9573
# Epoch 191/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1287 - accuracy: 0.9573
# Epoch 192/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1237 - accuracy: 0.9600
# Epoch 193/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1248 - accuracy: 0.9589
# Epoch 194/200
# 802/802 [==============================] - 12s 15ms/step - loss: 0.1235 - accuracy: 0.9598
# Epoch 195/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1210 - accuracy: 0.9589
# Epoch 196/200
# 802/802 [==============================] - 11s 14ms/step - loss: 0.1251 - accuracy: 0.9582
# Epoch 197/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1255 - accuracy: 0.9571
# Epoch 198/200
# 802/802 [==============================] - 12s 14ms/step - loss: 0.1222 - accuracy: 0.9585
# Epoch 199/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1220 - accuracy: 0.9601
# Epoch 200/200
# 802/802 [==============================] - 11s 13ms/step - loss: 0.1192 - accuracy: 0.9590
# <keras.src.callbacks.History object at 0x7c9add2eab60>
# 90/90 [==============================] - 1s 5ms/step - loss: 0.0725 - accuracy: 0.9737
#
#
# [0.07254016399383545, 0.9736841917037964]
# Ran  10 / 10 Fold in 2164.4162266254425 seconds ---

# %% [markdown]
# # Evaluation

# %%
best_model = load_model('fold7.P-1D-CNN.186-0.968.h5')

# %% [markdown]
# Additional necessary funtions

# %%
def split_vote(df):
    res = list()
    for i in range(len(df)):
        res += [window(df.iloc[i].values,w= 512, o = 256)]
    return np.asarray(res)

def count_votes(my_list):
    freq = {}
    for i in my_list:
        if (i in freq):
            freq[i] += 1
        else:
            freq[i] = 1
    return freq

def reshape_signal(signal):
    signal = np.expand_dims(signal, axis=1)
    signal = np.expand_dims(signal, axis=0)
    return np.asarray(signal)

def evaluate_subsignals(subsignals,model):
    vote_list = np.array([])
    for i in range(len(subsignals)):
        mini_signal = reshape_signal(subsignals[i])
        probabilities = model.predict(mini_signal)
        ynew = np.argmax(probabilities, axis=-1)
        # ynew = model.predict_classes(mini_signal)
        vote_list = np.append(vote_list, ynew)
    decision = count_votes(vote_list)
    return decision_to_str(decision), vote_list

def decision_to_str(dec):
    res = list()
    for key,val in dec.items():
        if key == 0:
            res += ['normal: ' + str(val) + ' votes' + '\n']
        if key == 1:
            res += ['ictal: ' + str(val) + ' votes' + '\n']
        if key == 2:
            res += ['interictal: ' + str(val) + ' votes' + '\n']
    return res

# %% [markdown]
# Exctracting 1st normal signal for testing

# %%
big_signal = split_vote(ictal_vote)
subsignals = big_signal[0]

# %% [markdown]
# It is divided into 15 subsignals of length 512, the model will "vote" on each subsignal and decide by majority

# %%
decision, vote_list = evaluate_subsignals(subsignals,best_model)
print(vote_list)
print(decision[0])
# Out:
# 1/1 [==============================] - 0s 355ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# [2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2. 2.]
# interictal: 15 votes
